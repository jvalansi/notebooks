# %%
! pip install pyaudio pyfluidsynth mido python-rtmidi
# Out:
# Requirement already satisfied: pyaudio in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (0.2.11)
# Requirement already satisfied: pyfluidsynth in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (1.2.5)
# Requirement already satisfied: mido in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (1.2.9)
# Collecting python-rtmidi
#   Downloading https://files.pythonhosted.org/packages/a7/e8/60472beaa24469aa7aa9a7bf218eddd9d593b6c8a35640d8de0c6a306841/python_rtmidi-1.3.0-cp36-cp36m-macosx_10_6_intel.whl (230kB)
#     100% |████████████████████████████████| 235kB 9.1MB/s eta 0:00:01
# Requirement already satisfied: future in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (from pyfluidsynth) (0.17.1)
# Installing collected packages: python-rtmidi
# Successfully installed python-rtmidi-1.3.0
# You are using pip version 19.0.3, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import mido
msg = mido.Message('note_on', note=60)

# %%
port = mido.open_output()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-94525fd3f10a> in <module>
# ----> 1 port = mido.open_output()
#
# ~/.virtualenv/notebooks/lib/python3.6/site-packages/mido/backends/backend.py in open_output(self, name, virtual, autoreset, **kwargs)
#     110             name = self._env('MIDO_DEFAULT_OUTPUT')
#     111
# --> 112         return self.module.Output(name, **self._add_api(kwargs))
#     113
#     114     def open_ioport(self, name=None, virtual=False,
#
# ~/.virtualenv/notebooks/lib/python3.6/site-packages/mido/ports.py in __init__(self, name, autoreset, **kwargs)
#     263         name is not passed, the default output is used instead.
#     264         """
# --> 265         BasePort.__init__(self, name, **kwargs)
#     266         self.autoreset = autoreset
#     267
#
# ~/.virtualenv/notebooks/lib/python3.6/site-packages/mido/ports.py in __init__(self, name, **kwargs)
#      84             self._lock = DummyLock()
#      85         self.closed = True
# ---> 86         self._open(**kwargs)
#      87         self.closed = False
#      88
#
# ~/.virtualenv/notebooks/lib/python3.6/site-packages/mido/backends/rtmidi.py in _open(self, client_name, virtual, api, callback, **kwargs)
#     188
#     189         self.name = _open_port(self._rt, self.name, client_name=client_name,
# --> 190                                virtual=virtual, api=self.api)
#     191         self.closed = False
#     192
#
# ~/.virtualenv/notebooks/lib/python3.6/site-packages/mido/backends/rtmidi.py in _open_port(rt, name, client_name, virtual, api)
#      83     port_names = rt.get_ports()
#      84     if len(port_names) == 0:
# ---> 85         raise IOError('no ports available')
#      86
#      87     if name is None:
#
# OSError: no ports available

# %%
mid = mido.MidiFile('my_music.midi')
for msg in mid.play():
    port.send(msg)

# %%
import time
import numpy
import pyaudio
import fluidsynth

pa = pyaudio.PyAudio()
strm = pa.open(
    format = pyaudio.paInt16,
    channels = 2, 
    rate = 44100, 
    output = True)

# strm = pa.open(format=p.get_format_from_width(wf.getsampwidth()),
#                 channels=2,#wf.getnchannels(),
#                 rate=44100,#wf.getframerate(),
#                 output=True)



s = []

fl = fluidsynth.Synth()

# Initial silence is 1 second
s = numpy.append(s, fl.get_samples(44100 * 1))

sfid = fl.sfload("example.sf2")
fl.program_select(0, sfid, 0, 0)

fl.noteon(0, 60, 30)
fl.noteon(0, 67, 30)
fl.noteon(0, 76, 30)

# Chord is held for 2 seconds
s = numpy.append(s, fl.get_samples(44100 * 2))

fl.noteoff(0, 60)
fl.noteoff(0, 67)
fl.noteoff(0, 76)

# Decay of chord is held for 1 second
s = numpy.append(s, fl.get_samples(44100 * 1))

fl.delete()

samps = fluidsynth.raw_audio_string(s)

print(len(samps))
print('Starting playback')
strm.write(samps)
# Out:
# 705600
# Starting playback

# %%
import time
import fluidsynth

fs = fluidsynth.Synth()
fs.start()

sfid = fs.sfload("example.sf1")
fs.program_select(0, sfid, 0, 0)

fs.noteon(0, 60, 30)
fs.noteon(0, 67, 30)
fs.noteon(0, 76, 30)

time.sleep(1.0)

fs.noteoff(0, 60)
fs.noteoff(0, 67)
fs.noteoff(0, 76)

time.sleep(1.0)

fs.delete()

# %%
import pyaudio
import wave
import sys

CHUNK = 1024

# if len(sys.argv) < 2:
#     print("Plays a wave file.\n\nUsage: %s filename.wav" % sys.argv[0])
#     sys.exit(-1)

wf = wave.open('test.wav', 'rb')

# instantiate PyAudio (1)
p = pyaudio.PyAudio()

# open stream (2)
stream = p.open(format=p.get_format_from_width(wf.getsampwidth()),
                channels=wf.getnchannels(),
                rate=wf.getframerate(),
                output=True)

# read data
data = wf.readframes(CHUNK)

# play stream (3)
while len(data) > 0:
    stream.write(data)
    data = wf.readframes(CHUNK)

# stop stream (4)
stream.stop_stream()
stream.close()

# close PyAudio (5)
p.terminate()

# %% [markdown]
# # pretty midi

# %%
! pip install pretty_midi
# Out:
# Collecting pretty_midi
# Requirement already satisfied: numpy>=1.7.0 in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (from pretty_midi) (1.16.2)
# Requirement already satisfied: six in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (from pretty_midi) (1.12.0)
# Requirement already satisfied: mido>=1.1.16 in /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages (from pretty_midi) (1.2.9)
# Installing collected packages: pretty-midi
# Successfully installed pretty-midi-0.2.8
# You are using pip version 19.0.3, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pretty_midi
# Load MIDI file into PrettyMIDI object
midi_data = pretty_midi.PrettyMIDI('/tmp/improv_rnn/generated/2019-09-14_224755_01.mid')
# Print an empirical estimate of its global tempo
print(midi_data.estimate_tempo())
# Compute the relative amount of each semitone across the entire song, a proxy for key
total_velocity = sum(sum(midi_data.get_chroma()))
print([sum(semitone)/total_velocity for semitone in midi_data.get_chroma()])
# Shift all notes up by 5 semitones
for instrument in midi_data.instruments:
    # Don't want to shift drum notes
    if not instrument.is_drum:
        for note in instrument.notes:
            note.pitch += 5
# Synthesize the resulting MIDI data using sine waves
audio_data = midi_data.synthesize()
# Out:
# 140.0
# [0.2648734898563939, 0.0, 0.07408251652609985, 0.0, 0.10257579211306132, 0.09117848187827672, 0.0, 0.21085023934351493, 0.0, 0.21085023934351493, 0.0, 0.04558924093913836]

# %%
audio_data
# Out:
# array([0.        , 0.03786247, 0.07565942, ..., 0.        , 0.        ,
#        0.        ])

# %%
import IPython

# %%
IPython.display.Audio(audio_data, rate=64000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
