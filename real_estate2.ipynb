# %%
# get price per metro
# get rent per metro
# get unemployment per metro
# find indicators for house price change

# %%
from itertools import product
import re
import pandas as pd
import numpy as np
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas()

# %%
home_forecast = pd.read_csv('data/real_estate/AllRegionsForePublic.csv')

# %%
median_rent = pd.read_csv('data/real_estate/City_MedianRentalPrice_AllHomes.csv')

# %%
zhvi = pd.read_csv('data/real_estate/City_Zhvi_Summary_AllHomes2.csv')

# %%
zri = pd.read_csv('data/real_estate/City_Zri_AllHomesPlusMultifamily_Summary2.csv')

# %%
rent_forecast = pd.read_csv('data/real_estate/ZriForecast_Public.csv')

# %%
sale_price = pd.read_csv('data/real_estate/Sale_Prices_City-2.csv')

# %%
# criteria:
    # minimize price to rent ratio
    # above average expected growth
    # reasonable house price (up to 50k down - 250k price)
    # close to home
    
# need to check:
    # tax
    # vacancy

# %% [markdown]
# # Price to Rent

# %%
median_rent['FullName'] = median_rent['RegionName'] + " " + median_rent['State']

# %%
median_rent.head()
# Out:
#     RegionName State                             Metro          CountyName  \
# 0     New York    NY       New York-Newark-Jersey City       Queens County
# 1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim  Los Angeles County
# 2      Houston    TX  Houston-The Woodlands-Sugar Land       Harris County
# 3      Chicago    IL          Chicago-Naperville-Elgin         Cook County
# 4  San Antonio    TX         San Antonio-New Braunfels        Bexar County
#
#    SizeRank  2010-01  2010-02  2010-03  2010-04  2010-05  ...  2019-01  \
# 0         1      NaN      NaN      NaN      NaN   2297.5  ...   2800.0
# 1         2      NaN      NaN      NaN      NaN      NaN  ...   3500.0
# 2         3      NaN      NaN      NaN      NaN      NaN  ...   1500.0
# 3         4      NaN   1600.0   1500.0   1500.0   1500.0  ...   1750.0
# 4         5      NaN      NaN      NaN      NaN      NaN  ...   1295.0
#
#    2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  \
# 0   2800.0   2800.0   2850.0   2900.0   2895.0   2850.0   2905.0   2900.0
# 1   3500.0   3500.0   3500.0   3500.0   3500.0   3500.0   3600.0   3607.0
# 2   1500.0   1500.0   1525.0   1550.0   1550.0   1550.0   1550.0   1550.0
# 3   1728.5   1775.0   1795.0   1800.0   1800.0   1800.0   1813.5   1800.0
# 4   1295.0   1300.0   1300.0   1325.0   1344.5   1349.0   1325.0   1299.5
#
#          FullName
# 0     New York NY
# 1  Los Angeles CA
# 2      Houston TX
# 3      Chicago IL
# 4  San Antonio TX
#
# [5 rows x 123 columns]

# %%
median_rent[median_rent['RegionName']== 'Birmingham']
# Out:
#       RegionName State                    Metro        CountyName  SizeRank  \
# 120   Birmingham    AL        Birmingham-Hoover  Jefferson County       121
# 1498  Birmingham    MI  Detroit-Warren-Dearborn    Oakland County      1499
#
#       2010-01  2010-02  2010-03  2010-04  2010-05  ...  2019-01  2019-02  \
# 120       NaN      NaN      NaN      NaN      NaN  ...    850.0    850.0
# 1498      NaN      NaN      NaN      NaN      NaN  ...   2000.0   2100.0
#
#       2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  \
# 120     850.0    885.0    900.0    895.0    885.0    850.0    850.0
# 1498   1972.5   1995.0   2000.0   2100.0   2200.0   2250.0   2200.0
#
#            FullName
# 120   Birmingham AL
# 1498  Birmingham MI
#
# [2 rows x 123 columns]

# %%
median_rent.isna().sum().tail(10)
# Out:
# 2019-01     0
# 2019-02     0
# 2019-03     0
# 2019-04     0
# 2019-05     0
# 2019-06     0
# 2019-07     0
# 2019-08     0
# 2019-09     0
# FullName    0
# dtype: int64

# %%
state_abbrev = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations')

# %%
state_abbrev_df = state_abbrev[0]

# %%
state_abbrev_dict = state_abbrev_df.T.reset_index(drop=True).T.set_index(0)[3].to_dict()

# %%
sale_price['StateAbbrev'] = sale_price['StateName'].apply(lambda x: state_abbrev_dict[x])

# %%
sale_price['FullName'] = sale_price['RegionName'] + " " + sale_price['StateAbbrev']

# %%
sale_price.head()
# Out:
#    RegionID    RegionName     StateName  SizeRank   2008-03   2008-04  \
# 0     12447   Los Angeles    California         1  502500.0  486800.0
# 1     17426       Chicago      Illinois         2  326200.0  316800.0
# 2     13271  Philadelphia  Pennsylvania         3  110400.0  110700.0
# 3     40326       Phoenix       Arizona         4  221600.0  212400.0
# 4     18959     Las Vegas        Nevada         5  245700.0  239900.0
#
#     2008-05   2008-06   2008-07   2008-08  ...   2019-02   2019-03   2019-04  \
# 0  463300.0  454100.0  434500.0  420500.0  ...  684700.0  698200.0  700600.0
# 1  293300.0  279000.0  273600.0  270100.0  ...  269200.0  299600.0  299600.0
# 2  111700.0  110200.0  108400.0  111200.0  ...  157300.0  156000.0  158500.0
# 3  204300.0  195700.0  186400.0  176600.0  ...  228300.0  232700.0  233100.0
# 4  235100.0  226000.0  217800.0  207600.0  ...  267800.0  270900.0  266400.0
#
#     2019-05   2019-06   2019-07   2019-08   2019-09  StateAbbrev  \
# 0  705800.0  708900.0  711700.0  714300.0  710400.0           CA
# 1  290000.0  281500.0  277100.0  273200.0  272400.0           IL
# 2  159600.0  163700.0  165700.0  169800.0       NaN           PA
# 3  235000.0  236900.0  237500.0  236000.0  237400.0           AZ
# 4  266600.0  265900.0  269700.0  271200.0  271700.0           NV
#
#           FullName
# 0   Los Angeles CA
# 1       Chicago IL
# 2  Philadelphia PA
# 3       Phoenix AZ
# 4     Las Vegas NV
#
# [5 rows x 145 columns]

# %%
sale_price[sale_price['RegionName']== 'Birmingham']
# Out:
# Empty DataFrame
# Columns: [RegionID, RegionName, StateName, SizeRank, 2008-03, 2008-04, 2008-05, 2008-06, 2008-07, 2008-08, 2008-09, 2008-10, 2008-11, 2008-12, 2009-01, 2009-02, 2009-03, 2009-04, 2009-05, 2009-06, 2009-07, 2009-08, 2009-09, 2009-10, 2009-11, 2009-12, 2010-01, 2010-02, 2010-03, 2010-04, 2010-05, 2010-06, 2010-07, 2010-08, 2010-09, 2010-10, 2010-11, 2010-12, 2011-01, 2011-02, 2011-03, 2011-04, 2011-05, 2011-06, 2011-07, 2011-08, 2011-09, 2011-10, 2011-11, 2011-12, 2012-01, 2012-02, 2012-03, 2012-04, 2012-05, 2012-06, 2012-07, 2012-08, 2012-09, 2012-10, 2012-11, 2012-12, 2013-01, 2013-02, 2013-03, 2013-04, 2013-05, 2013-06, 2013-07, 2013-08, 2013-09, 2013-10, 2013-11, 2013-12, 2014-01, 2014-02, 2014-03, 2014-04, 2014-05, 2014-06, 2014-07, 2014-08, 2014-09, 2014-10, 2014-11, 2014-12, 2015-01, 2015-02, 2015-03, 2015-04, 2015-05, 2015-06, 2015-07, 2015-08, 2015-09, 2015-10, 2015-11, 2015-12, 2016-01, 2016-02, ...]
# Index: []
#
# [0 rows x 146 columns]

# %%
sale_price.isna().sum().tail(10)
# Out:
# 2019-02           1
# 2019-03          22
# 2019-04          29
# 2019-05          53
# 2019-06          98
# 2019-07         110
# 2019-08         150
# 2019-09        1836
# StateAbbrev      11
# FullName         11
# dtype: int64

# %%
sale_price_2019 = sale_price.set_index('FullName').loc[:,'2019-02']

# %%
sale_price_2019.name = 'price'

# %%
median_rent_2019 = median_rent.set_index('FullName').loc[:,'2019-02']

# %%
median_rent_2019.name = 'rent'

# %%
sale_price_2019.head()
# Out:
# FullName
# Los Angeles CA     684700.0
# Chicago IL         269200.0
# Philadelphia PA    157300.0
# Phoenix AZ         228300.0
# Las Vegas NV       267800.0
# Name: price, dtype: float64

# %%
median_rent_2019.head()
# Out:
# FullName
# New York NY       2800.0
# Los Angeles CA    3500.0
# Houston TX        1500.0
# Chicago IL        1728.5
# San Antonio TX    1295.0
# Name: rent, dtype: float64

# %%
city_df = median_rent_2019.to_frame().merge(sale_price_2019.to_frame(), left_index=True, right_index=True)

# %%
city_df = city_df.dropna()

# %%
city_df.head()
# Out:
#                    rent     price
# FullName
# Abingdon MD      1650.0  229500.0
# Acworth GA       1500.0  238300.0
# Agoura Hills CA  3450.0  987400.0
# Aiken SC         1225.0  140200.0
# Akron OH          775.0   68300.0

# %%
city_df['price_to_rent'] = city_df['price']/city_df['rent']

# %%
city_df = city_df.sort_values(by='price_to_rent')

# %%
city_df['price_to_rent'].hist()

# %% [markdown]
# # Forecast

# %%
home_forecast['Region'].unique()
# Out:
# array(['Country', 'State', 'County', 'Msa', 'City', 'Neighborhood', 'Zip'],
#       dtype=object)

# %%
home_forecast = home_forecast[home_forecast['Region']=='City']

# %%
home_forecast['FullName'] = home_forecast['CityName'] + " " + home_forecast['StateName']

# %%
home_forecast.head()
# Out:
#             Region RegionName StateName           CountyName  CityName  \
# FullName
# Aberdeen ID   City   Aberdeen        ID       Bingham County  Aberdeen
# Aberdeen NC   City   Aberdeen        NC         Moore County  Aberdeen
# Aberdeen MD   City   Aberdeen        MD       Harford County  Aberdeen
# Aberdeen WA   City   Aberdeen        WA  Grays Harbor County  Aberdeen
# Aberdeen MS   City   Aberdeen        MS        Monroe County  Aberdeen
#
#              ForecastYoYPctChange
# FullName
# Aberdeen ID              6.723185
# Aberdeen NC              2.615473
# Aberdeen MD              2.133168
# Aberdeen WA              5.370652
# Aberdeen MS              1.907417

# %%
home_forecast = home_forecast.set_index('FullName')

# %%
home_forecast = home_forecast[~home_forecast.index.duplicated()]

# %%
city_df = city_df[~city_df.index.duplicated()]

# %%
city_df['forecast'] = home_forecast['ForecastYoYPctChange']

# %%
city_df['state'] = home_forecast['StateName']

# %%
city_df[city_df['state']=='AL']
# Out:
#                  rent     price  price_to_rent  forecast state
# FullName
# Hueytown AL     900.0   97100.0     107.888889  1.529017    AL
# Montgomery AL   850.0  107700.0     126.705882  1.059200    AL
# Dothan AL      1100.0  139600.0     126.909091 -1.260515    AL
# Foley AL       1350.0  180000.0     133.333333  2.516662    AL
# Calera AL      1250.0  167400.0     133.920000  3.361010    AL
# Daphne AL      1300.0  179600.0     138.153846  1.347739    AL
# Alabaster AL   1250.0  183200.0     146.560000  4.089921    AL
# Madison AL     1350.0  200100.0     148.222222  2.399132    AL
# Tuscaloosa AL  1350.0  201700.0     149.407407  2.362939    AL
# Huntsville AL   995.0  156500.0     157.286432  1.791017    AL
# Fairhope AL    1690.0  293700.0     173.786982  1.510003    AL
# Hoover AL      1597.5  288800.0     180.782473  2.794662    AL

# %%
city_df[city_df.forecast>1].head(50)
# Out:
#                         rent     price  price_to_rent  forecast state
# FullName
# Maple Heights OH       930.0   52400.0      56.344086  2.260637    OH
# Century Village FL     950.0   55500.0      58.421053  4.202020    FL
# South Holland IL      1902.0  118100.0      62.092534  1.667838    IL
# Rochester NY          1100.0   72700.0      66.090909  1.492843    NY
# South Euclid OH       1150.0   79300.0      68.956522  1.702731    OH
# Syracuse NY           1200.0   83600.0      69.666667  3.404178    NY
# Euclid OH              975.0   73600.0      75.487179  3.361613    OH
# Englewood FL          2600.0  199100.0      76.576923  1.298288    FL
# Ewing NJ              2025.0  160500.0      79.259259  1.861157    NJ
# Golden Lakes FL       1250.0   99500.0      79.600000  4.064901    FL
# Waterbury CT          1150.0   93600.0      81.391304  8.421664    CT
# Loughman FL           2670.0  218000.0      81.647940  3.479332    FL
# Lincoln Park MI        900.0   73800.0      82.000000  8.231310    MI
# Lansing IL            1475.0  126900.0      86.033898  1.078006    IL
# Penn Hills PA          995.0   87100.0      87.537688  1.922607    PA
# Upper Darby PA        1200.0  105500.0      87.916667  7.427425    PA
# Akron OH               775.0   68300.0      88.129032  4.492984    OH
# Del City OK            800.0   71400.0      89.250000  1.913804    OK
# Cleveland Heights OH  1195.0  107100.0      89.623431  3.725484    OH
# Rotonda West FL       2750.0  250200.0      90.981818  2.313310    FL
# Eastpointe MI          975.0   88800.0      91.076923  8.323136    MI
# Pottstown PA          1272.5  117100.0      92.023576  4.050963    PA
# Rock Island IL         875.0   80700.0      92.228571  1.168497    IL
# Delray Beach FL       1900.0  175700.0      92.473684  5.196956    FL
# West Haven CT         1800.0  167200.0      92.888889  2.204434    CT
# Nokomis FL            3275.0  304400.0      92.946565  1.381947    FL
# Coconut Creek FL      1775.0  165700.0      93.352113  2.442711    FL
# East Stroudsburg PA   1400.0  130900.0      93.500000  3.229721    PA
# Deerfield Beach FL    1600.0  151200.0      94.500000  3.379472    FL
# Palm Desert CA        3400.0  326400.0      96.000000  2.627963    CA
# Margate FL            1750.0  169600.0      96.914286  3.192382    FL
# Willingboro NJ        1600.0  155300.0      97.062500  2.023091    NJ
# Roseville MI           997.5   97400.0      97.644110  8.052215    MI
# La Quinta CA          4500.0  440400.0      97.866667  2.914988    CA
# New Haven CT          1400.0  137700.0      98.357143  1.392616    CT
# Brunswick GA          1299.0  128200.0      98.691301  3.089026    GA
# Ives Estates FL       1850.0  182600.0      98.702703  3.341282    FL
# Providence RI         2100.0  207500.0      98.809524  2.945463    RI
# Redford MI            1050.0  103800.0      98.857143  5.855042    MI
# Oak Lawn IL           1595.0  158100.0      99.122257  1.866941    IL
# Rockford IL            875.0   86800.0      99.200000  2.421923    IL
# Toledo OH              795.0   79800.0     100.377358  2.758024    OH
# Allentown PA          1250.0  127200.0     101.760000  4.676368    PA
# Hamden CT             1795.0  183200.0     102.061281  1.419406    CT
# Lake Placid FL        1200.0  126500.0     105.416667  2.227635    FL
# Parma OH              1085.0  114700.0     105.714286  2.464222    OH
# Riviera Beach FL      2200.0  232800.0     105.818182  3.786743    FL
# Greenacres FL         1425.0  151000.0     105.964912  4.050576    FL
# Waukegan IL           1312.5  139300.0     106.133333  6.796353    IL
# Dearborn Heights MI   1100.0  116800.0     106.181818  3.275387    MI

# %% [markdown]
# # Vacancy

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/80/93/d384479da0ead712bdaf697a8399c13a9a89bd856ada5a27d462fb45e47b/geopy-1.20.0-py2.py3-none-any.whl (100kB)
#     100% |████████████████████████████████| 102kB 4.2MB/s a 0:00:011
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-1.20.0
# You are using pip version 19.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import time

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
def get_geocode(name):
    time.sleep(1)
    return geolocator.geocode(name).point
# Out:
# /Users/jordanvalansi/.virtualenv/notebooks/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.

# %%
# city_df['geocode'] = city_df.reset_index()['FullName'].progress_apply(get_geocode)

# %%
df = pd.read_csv('data/real_estate/ann18t_8.csv', header=5, index_col=1)

# %%
def format_city(city):
    """
    convert
    >>> list(format_city("Allentown-Bethlehem-Easton, PA-NJ"))
    ['Allentown PA', 'Allentown NJ', 'Bethlehem PA', 'Bethlehem NJ', 'Easton PA', 'Easton NJ']
    """
    try:
        city = re.sub('[\.…]', '', city)
        cities, states = city.split(", ")
        cities = cities.split('-')
        states = states.split('-')
        return pd.Series([c+' '+re.sub('\d', '', s) for c,s in product(cities, states)])
    except (ValueError,AttributeError,TypeError):
        return pd.Series()

# %%
from doctest import testmod
testmod()
# Out:
# TestResults(failed=0, attempted=1)

# %%
df = df.reset_index()

# %%
df = df.dropna(subset=['2018'])

# %%
new_index = df['index'].progress_apply(format_city).stack().to_frame()
# Out:
# HBox(children=(IntProgress(value=0, max=76), HTML(value='')))

# %%
df.head()
# Out:
#                                                index Unnamed: 0  2015  2016  \
# 1    Inside Metropolitan Statistical Areas..........        NaN  11.3  11.3
# 3  Akron, OH .......................................        NaN  11.6  10.4
# 4  Albany-Schenectady-Troy, NY .....................        NaN  13.2  11.8
# 5  Albuquerque, NM..................................        NaN   9.3   9.2
# 6  Allentown-Bethlehem-Easton, PA-NJ................        NaN   9.1   7.4
#
#    2017  2018  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 1  11.3  10.8         NaN         NaN         NaN         NaN          NaN
# 3   8.8   5.6         NaN         NaN         NaN         NaN          NaN
# 4  10.5  11.6         NaN         NaN         NaN         NaN          NaN
# 5   8.9   8.3         NaN         NaN         NaN         NaN          NaN
# 6   9.5   9.3         NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 1          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN

# %%
new_index = new_index.reset_index()

# %%
new_df = new_index.reset_index().merge(df, left_on='level_0', right_index=True)

# %%
vacancy_df = new_df.set_index(0)['2018'].to_frame()

# %%
vacancy_df.loc['Hayward CA']
# Out:
# 2018    7.5
# Name: Hayward CA, dtype: float64

# %%
city_df.merge(vacancy_df, left_index=True, right_index=True)
# Out:
#                        rent      price  price_to_rent  forecast state  2018
# Rochester NY         1100.0    72700.0      66.090909  1.492843    NY   9.9
# Syracuse NY          1200.0    83600.0      69.666667  3.404178    NY  10.8
# Cleveland OH          900.0    66900.0      74.333333       NaN   NaN  10.4
# Easton PA            1300.0   102100.0      78.538462       NaN   NaN   9.3
# Baltimore MD         1345.0   115600.0      85.947955 -0.165009    MD  10.1
# New Haven CT         1400.0   137700.0      98.357143  1.392616    CT  10.9
# Providence RI        2100.0   207500.0      98.809524  2.945463    RI  10.3
# Toledo OH             795.0    79800.0     100.377358  2.758024    OH  12.3
# Allentown PA         1250.0   127200.0     101.760000  4.676368    PA   9.3
# Philadelphia PA      1450.0   157300.0     108.482759  0.675222    PA   9.0
# Memphis TN            895.0    98000.0     109.497207       NaN   NaN  12.6
# Bridgeport CT        1600.0   181400.0     113.375000  4.160442    CT  10.4
# Bethlehem PA         1395.0   158900.0     113.906810  1.597203    PA   9.3
# Grand Rapids MI      1450.0   165300.0     114.000000  4.162719    MI   8.9
# Clearwater FL        1679.0   191600.0     114.115545  4.340478    FL  16.1
# Dearborn MI          1200.0   138100.0     115.083333       NaN   NaN   9.2
# Pittsburgh PA        1400.0   164100.0     117.214286 -0.794372    PA  10.2
# Jacksonville FL      1245.0   147900.0     118.795181  4.337453    FL  10.1
# West Palm Beach FL   1750.0   211700.0     120.971429  3.637996    FL  14.9
# Columbus OH          1300.0   158700.0     122.076923  4.549390    OH   7.4
# Fort Myers FL        1685.0   206600.0     122.611276  1.669700    FL  41.5
# Columbia SC          1159.0   143100.0     123.468507  2.810711    SC   8.9
# Cincinnati OH        1262.5   156000.0     123.564356  3.333308    OH   6.8
# Atlanta GA           1795.0   225600.0     125.682451  4.406528    GA   7.8
# Bradenton FL         1865.0   234500.0     125.737265  3.071042    FL  31.5
# Elgin IL             1575.0   199100.0     126.412698  1.379405    IL   7.5
# Sarasota FL          2000.0   255400.0     127.700000  2.764558    FL  31.5
# Miami FL             2400.0   307500.0     128.125000 -0.500066    FL  14.9
# North Port FL        1500.0   192600.0     128.400000  3.364985    FL  31.5
# North Charleston SC  1350.0   173800.0     128.740741  4.127643    SC  16.0
# ...                     ...        ...            ...       ...   ...   ...
# Vancouver WA         1750.0   333600.0     190.628571  2.829414    WA   6.8
# Stamford CT          2250.0   437600.0     194.488889  0.430084    CT  10.4
# Los Angeles CA       3500.0   684700.0     195.628571  2.511934    CA   6.6
# Denver CO            2100.0   411600.0     196.000000  0.356462    CO   8.0
# Henderson NV         1595.0   316700.0     198.557994  0.056211    NV  11.4
# Franklin TN          2300.0   458300.0     199.260870  3.147343    TN   5.9
# Riverside CA         2050.0   425000.0     207.317073  1.768278    CA  15.1
# Hillsboro OR         1800.0   374200.0     207.888889  2.250203    OR   6.8
# Washington DC        2600.0   550700.0     211.807692 -1.318275    DC   7.0
# Anaheim CA           2675.0   580300.0     216.934579  2.489650    CA   6.6
# Portland OR          1950.0   423800.0     217.333333 -1.850099    OR   6.8
# Boston MA            2900.0   631400.0     217.724138  1.255775    MA   7.5
# Alexandria VA        2225.0   490600.0     220.494382       NaN   NaN   7.0
# San Diego CA         2700.0   596000.0     220.740741  1.490403    CA   7.6
# Roseville CA         2095.0   469700.0     224.200477  3.100336    CA   8.6
# Austin TX            1695.0   384800.0     227.020649  3.577361    TX   9.7
# Oakland CA           2995.0   699100.0     233.422371  2.005532    CA   7.5
# Lakewood CO          1700.0   397100.0     233.588235  1.755486    CO   8.0
# Carlsbad CA          3397.5   825000.0     242.825607  0.998432    CA   7.6
# Long Beach CA        2250.0   557400.0     247.733333  2.631025    CA   6.6
# Salt Lake City UT    1595.0   402800.0     252.539185  4.405318    UT   5.0
# Arlington VA         2390.0   608200.0     254.476987  2.761909    VA   7.0
# Hayward CA           2500.0   648700.0     259.480000  0.220229    CA   7.5
# Seattle WA           2575.0   670200.0     260.271845 -2.032694    WA   5.9
# Cambridge MA         3000.0   836300.0     278.766667  1.130238    MA   7.5
# San Jose CA          3395.0   972300.0     286.391753       NaN   NaN   5.8
# Bellevue WA          2775.0   839200.0     302.414414 -2.203857    WA   5.9
# Newton MA            3200.0   993100.0     310.343750  0.675389    MA   7.5
# Santa Clara CA       3500.0  1165700.0     333.057143       NaN   NaN   5.8
# Sunnyvale CA         3800.0  1453600.0     382.526316       NaN   NaN   5.8
#
# [120 rows x 6 columns]

# %%
# TODO: Add crime rate
